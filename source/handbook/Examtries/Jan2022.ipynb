# %% [markdown]
# # Exam 2022 January

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
#
# There are 4 atoms inside the unit cell
#
# - 2 of each
#
#
# -----

# %% [markdown]
# ![](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
#
# -----

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# $$
# e^{i\mathbf{G \cdot (r + R)}}
# $$

# %% [markdown]
# where **r** is a point vector.
#
# one can also write it like the following:
#
# $$
# e^{i\mathbf{G \cdot R}}e^{i\mathbf{G \cdot r}} = e^{i\mathbf{G \cdot r}}
# $$
#
# as
#
# $$
# e^{i\mathbf{G \cdot R}} = 1
# $$
#
# -----

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![Alt text](../../figures/Examtries/image.png)
#
# ![Alt text](../../figures/Examtries/image-1.png)

# %% [markdown]
# ![Alt text](../../figures/Examtries/image-2.png)

# %% [markdown]
# ![Alt text](../../figures/Examtries/image-3.png)
